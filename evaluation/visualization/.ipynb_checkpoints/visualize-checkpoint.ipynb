# %%
import h5py
import modin.pandas as pd
# Out:
# Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-03-05_12-39-53_74976/logs.
# Waiting for redis server at 127.0.0.1:25862 to respond...
# Waiting for redis server at 127.0.0.1:27184 to respond...
# Starting Redis shard with 10.0 GB max memory.
# Starting the Plasma object store with 10.0 GB memory using /tmp.

# %%
fpath = '../../data/wiki-news-300d-1M-subword_hdim_1000_batch_size_64_num_epochs_1000_sparsity_0.85_optim_adam.hdf5.spine'
with h5py.File(fpath) as f:
    words, vectors = f['words'][()], f['vectors'][()]
    df = pd.DataFrame(vectors, index=words, columns=[f'd{i}' for i in range(1, vectors.shape[1]+1)])

# %%
df.sort_values('d1', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-44a7b86bc897> in <module>()
# ----> 1 df.sort_values('d1')
#
# ~/anaconda/lib/python3.6/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# ~/anaconda/lib/python3.6/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/kyoungrok/anaconda/lib/python3.6/site-packages/decorator.py:decorator-gen-10> in __call__(self, obj)
#
# ~/anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# ~/anaconda/lib/python3.6/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     509         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 510         _repr_pprint(obj, p, cycle)
#     511         return
#     512     p.begin_group(1, '<')
#
# ~/anaconda/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# ~/anaconda/lib/python3.6/site-packages/modin/pandas/dataframe.py in __repr__(self)
#     124         num_cols = 30
#     125
# --> 126         result = repr(self._build_repr_df(num_rows, num_cols))
#     127         if len(self.index) > num_rows or len(self.columns) > num_cols:
#     128             # The split here is so that we don't repr pandas row lengths.
#
# ~/anaconda/lib/python3.6/site-packages/modin/pandas/dataframe.py in _build_repr_df(self, num_rows, num_cols)
#      91             tail = None
#      92         else:
# ---> 93             head = self._query_compiler.head(num_rows_for_head)
#      94             tail = self._query_compiler.tail(num_rows_for_head)
#      95
#
# ~/anaconda/lib/python3.6/site-packages/modin/data_management/query_compiler/pandas_query_compiler.py in head(self, n)
#    2081         else:
#    2082             result = self.__constructor__(
# -> 2083                 self.data.take(0, n), self.index[:n], self.columns, self._dtype_cache
#    2084             )
#    2085         return result
#
# ~/anaconda/lib/python3.6/site-packages/modin/engines/base/block_partitions.py in take(self, axis, n)
#     331         # These are the partitions that we will extract over
#     332         if not axis:
# --> 333             partitions = self.partitions
#     334             bin_lengths = self.block_lengths
#     335         else:
#
# ~/anaconda/lib/python3.6/site-packages/modin/engines/base/block_partitions.py in _get_partitions(self)
#      66                             if self.block_lengths[i] != 0 and self.block_widths[j] != 0
#      67                         ]
# ---> 68                         for i in range(len(self._partitions_cache))
#      69                     ]
#      70                     if len(row)
#
# ~/anaconda/lib/python3.6/site-packages/modin/engines/base/block_partitions.py in <listcomp>(.0)
#      66                             if self.block_lengths[i] != 0 and self.block_widths[j] != 0
#      67                         ]
# ---> 68                         for i in range(len(self._partitions_cache))
#      69                     ]
#      70                     if len(row)
#
# ~/anaconda/lib/python3.6/site-packages/modin/engines/base/block_partitions.py in <listcomp>(.0)
#      64                             self._partitions_cache[i][j]
#      65                             for j in range(len(self._partitions_cache[i]))
# ---> 66                             if self.block_lengths[i] != 0 and self.block_widths[j] != 0
#      67                         ]
#      68                         for i in range(len(self._partitions_cache))
#
# ~/anaconda/lib/python3.6/site-packages/modin/engines/ray/pandas_on_ray/block_partitions.py in block_lengths(self)
#      39             self._lengths_cache = np.array(
#      40                 ray.get([obj.length().oid for obj in self._partitions_cache.T[0]])
# ---> 41                 if len(self._partitions_cache.T) > 0
#      42                 else []
#      43             )
#
# ~/anaconda/lib/python3.6/site-packages/ray/worker.py in get(object_ids, worker)
#    2196         global last_task_error_raise_time
#    2197         if isinstance(object_ids, list):
# -> 2198             values = worker.get_object(object_ids)
#    2199             for i, value in enumerate(values):
#    2200                 if isinstance(value, RayTaskError):
#
# ~/anaconda/lib/python3.6/site-packages/ray/worker.py in get_object(self, object_ids)
#     494                     max([
#     495                         ray._config.get_timeout_milliseconds(),
# --> 496                         int(0.01 * len(unready_ids)),
#     497                     ]),
#     498                 )
#
# ~/anaconda/lib/python3.6/site-packages/ray/worker.py in retrieve_and_deserialize(self, object_ids, timeout, error_timeout)
#     396                             i + ray._config.worker_get_request_size())],
#     397                         timeout,
# --> 398                         self.get_serialization_context(self.task_driver_id))
#     399                 return results
#     400             except pyarrow.lib.ArrowInvalid:
#
# ~/anaconda/lib/python3.6/site-packages/ray/utils.py in _wrapper(*args, **kwargs)
#     435                 def _wrapper(*args, **kwargs):
#     436                     with self.lock:
# --> 437                         return orig_attr(*args, **kwargs)
#     438
#     439                 self._wrapper_cache[attr] = _wrapper
#
# ~/anaconda/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.PlasmaClient.get()
#
# ~/anaconda/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.PlasmaClient.get_buffers()
#
# ~/anaconda/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.PlasmaClient._get_object_buffers()
#
# ~/anaconda/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/error.pxi in pyarrow.lib.check_status()
#
# ~/anaconda/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/compat.py in frombytes(o)
#     140             return o
#     141
# --> 142     def frombytes(o):
#     143         return o.decode('utf8')
#     144
#
# KeyboardInterrupt:
